# %% [markdown]
# ### Classification of Training data:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bag of words:
#
# It is method of feature extraction with text data. In other words, it is converting the textual format data(vector) to a numrical format(vector).
# 1. The variable length texts are converted into fixed length **vector**.
# 2. Then the vector is mapped with 0s and 1s.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Tokenisation:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Stemming
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Process pipeline
#
# ![image.png](attachment:image.png)
